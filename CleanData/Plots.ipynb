# %% [markdown]
# # Data display

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from jupyterthemes import jtplot
# %matplotlib inline
# Because I use jupyter themes is neccesary to indicate the parameters 
jtplot.style('monokai', grid=False, ticks=True)

data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# 5       AL             118        510  391-8027        yes         no
# 6       MA             121        510  355-9993         no        yes
# 7       MO             147        415  329-9001        yes         no
# 8       LA             117        408  335-4719         no         no
# 9       WV             141        415  330-8173        yes        yes
# 10      IN              65        415  329-6603         no         no
# 11      RI              74        415  344-9403         no         no
# ...

# %%
# To save the data as one image
# savefig("path to save the file")

# %% [markdown]
# ### Scatter plot

# %%
ax = data.plot( kind='scatter', x="Day Mins", y="Day Charge", c='#3572c5', alpha=0.5, linewidth=0)
# Specify background color for the axis/plot
ax.set_facecolor("#aaaaaa")

# %%
ay = data.plot( kind='scatter', x="Night Mins", y="Night Charge", c='#3572c5', alpha=0.5, linewidth=0)
# Specify background color for the axis/plot
ay.set_facecolor("#aaaaaa")

# %%
# Create a subplot
figure, axs = plt.subplots(2, 2, sharey=True, sharex=True)
# Generate the plots
data.plot( kind='scatter', x="Day Mins", y="Day Charge", c='#3572c5', ax=axs[0][0])
data.plot( kind='scatter', x="Night Mins", y="Night Charge", c='#3572c5', ax=axs[0][1])
data.plot( kind='scatter', x="Day Calls", y="Day Charge", c='#3572c5', ax=axs[1][0])
data.plot( kind='scatter', x="Night Calls", y="Night Charge", c='#3572c5', ax=axs[1][1])
# Change the color of the background of the subplost
for x in range(2):
    for y in range(2):
        axs[x, y].set_facecolor('#aaaaaa')

# %% [markdown]
# ### Frequency histogram
#
# They serve to obtain a general "first glance", or panorama, of the distribution of the population, or of the sample, with respect to a characteristic, quantitative and continuous (such as length or weight).
#
# With Numpy 1.11 or newer, you can alternatively provide a string describing a binning strategy, such as 'auto', 'sturges', 'fd', 'doane', 'scott', 'rice', 'sturges' or 'sqrt', see numpy.histogram.
#
# [Reference matplotlib.pyplot.hist](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html)
# [Reference numpy.histogram](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.histogram.html)

# %%
# Calculation of Sturges law
# k =  int(np.ceil(1+np.log2(3333))) # Where 3333 is the number of samples

# %%
#plt.style.use('default')
# hist() will make an histogram
plt.hist(data["Day Calls"], bins="sturges") # same has if we write bin=[5]
plt.xlabel("Number of day calls")
plt.ylabel("Frequency")
plt.title("Histogram of number of calls per day")
# Out:
# Text(0.5, 1.0, 'Histogram of number of calls per day')
