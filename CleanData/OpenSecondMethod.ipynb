# %%
import pandas as pd 
import os

# %%
mainpath = "/Users/avega/Documents/Github/Python/datasets/"

# %%
# "r" indicate that is just for lecture
# ImporT the text to a list 
with open(mainpath + "/" + "customer-churn-model/Customer Churn Model.txt", "r") as data:
    lines = data.readlines()

# %%
# strip the enter and convert split it in to a list 
col_names = lines[0].strip("\n").split(",")
n_cols = len(col_names)
# col_names

# %%
# Create the dictionary 
counter = 0 
main_dict = {}
for col in col_names:
    main_dict[col] = []

# %%
# main_dict

# %%
# Navigate in the list 
for line in lines:
    # Jump in the second place of the list because the 0 is for the header
    if counter > 0:
        # strip possibles blanks and split the values inside of each value of the list that are separated by comas
        values = line.strip().split(",")
        # Add each value in the column 
        for i in range(n_cols):
            main_dict[cols[i]].append(values[i])
    counter += 1
        
print("The data set has {} rows and {} columns".format(counter, n_cols))
# Out:
# The data set has 3334 rows and 21 columns

# %%
df = pd.DataFrame(main_dict)
df
# Out:
#      State Account Length Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS            128       415  382-4657         no        yes
# 1       OH            107       415  371-7191         no        yes
# 2       NJ            137       415  358-1921         no         no
# 3       OH             84       408  375-9999        yes         no
# 4       OK             75       415  330-6626        yes         no
# 5       AL            118       510  391-8027        yes         no
# 6       MA            121       510  355-9993         no        yes
# 7       MO            147       415  329-9001        yes         no
# 8       LA            117       408  335-4719         no         no
# 9       WV            141       415  330-8173        yes        yes
# 10      IN             65       415  329-6603         no         no
# 11      RI             74       415  344-9403         no         no
# 12      IA            168       408  363-1107         no         no
# ...
